# %% [markdown]
# # Cash Secured Puts
# This notebook will help find opportunities when selling put options.

# %%
from Tools.options_chain import OptionsChain

ticker = "RIVN"
oc = OptionsChain(ticker, buy=False, sell= True) 
oc.set_all() # Set all class data.
puts = oc.get_puts() # Get the puts from the chain
puts = puts[puts["sell_credit"] > 0].reset_index(drop=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0   RIVN250207P00010000 2025-01-31 17:37:43+00:00    10.0       0.02  0.01
# 1   RIVN250207P00010500 2025-01-31 20:35:18+00:00    10.5       0.02  0.01
# 2   RIVN250207P00011000 2025-01-31 20:58:16+00:00    11.0       0.04  0.04
# 3   RIVN250207P00011500 2025-01-31 20:58:53+00:00    11.5       0.10  0.09
# 4   RIVN250207P00012000 2025-01-31 20:59:51+00:00    12.0       0.22  0.22
# 5   RIVN250207P00012500 2025-01-31 20:57:37+00:00    12.5       0.41  0.41
# 6   RIVN250207P00013000 2025-01-31 20:55:42+00:00    13.0       0.72  0.70
# 7   RIVN250207P00013500 2025-01-31 20:40:02+00:00    13.5       1.10  1.07
# 8   RIVN250207P00014000 2025-01-31 20:36:43+00:00    14.0       1.47  1.40
# 9   RIVN250207P00014500 2025-01-31 20:36:06+00:00    14.5       1.98  1.86
# 10  RIVN250207P00015000 2025-01-31 19:55:24+00:00    15.0       2.49  1.97
# ...

# %% [markdown]
# # In depth View
#
# Choose an index from the option list above.

# %%
row = puts.iloc[0]
strike = row["strike"]
expiration = row["expirationDate"]
bt = oc.backtest.get_probability(strike, option_type="put", expiration_date=expiration, return_value=False)
prem = f"\n----------\nPremium: {row['sell_credit']}\nPremium(Mark): {row['sell_credit_mark']}\nCollateral: {row['sell_collateral']}\nYield: {row['sell_yield']}%"
bt += prem
print(bt)
# Out:
# ROW: contractSymbol            RIVN250207P00010000
# lastTradeDate       2025-01-31 17:37:43+00:00
# strike                                   10.0
# lastPrice                                0.02
# bid                                      0.01
# ask                                      0.05
# mark                                     0.03
# change                                   0.01
# change%                                100.00
# volume                                  115.0
# OI                                        532
# volume/OI                                0.22
# IV                                       1.06
# ITM                                     False
# expirationDate                     2025-02-07
# DTE                                         6
# sell_collateral                        1000.0
# sell_credit                               1.0
# sell_credit_mark                          3.0
# sell_yield                                0.1
# ...
